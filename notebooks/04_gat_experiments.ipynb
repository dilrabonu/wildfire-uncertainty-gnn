# %%
import os
import sys

os.chdir("..")
sys.path.append("src")

# %%
import copy
import torch
import pandas as pd
import matplotlib.pyplot as plt

from wildfire_gnn.utils.config import load_yaml_config
from wildfire_gnn.pipelines.gat_pipeline import GNNPipeline
from wildfire_gnn.features.feature_engineering_5b import (
    set_feature_names,
    get_feature_names,
    add_degree_feature,
    add_neighborhood_summary_features,
    add_two_hop_summary_features,
    add_feature_interactions,
    subset_graph_features,
)
from wildfire_gnn.data.graph_splitters import (
    attach_masks_from_split_file,
    print_mask_summary,
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       4 import matplotlib.pyplot as plt
#       6 from wildfire_gnn.utils.config import load_yaml_config
# ----> 7 from wildfire_gnn.pipelines.gat_pipeline import GNNPipeline
#       8 from wildfire_gnn.features.feature_engineering_5b import (
#       9     set_feature_names,
#      10     get_feature_names,
#    (...)     15     subset_graph_features,
#      16 )
#      17 from wildfire_gnn.data.graph_splitters import (
#      18     attach_masks_from_split_file,
#      19     print_mask_summary,
#      20 )
#
# File D:\wildfire-uncertainty-gnn\src\wildfire_gnn\pipelines\gat_pipeline.py:10
#       8 import pandas as pd
#       9 import torch
# ---> 10 from torch_geometric.data import Data
#      12 from wildfire_gnn.models.gat_models import GraphSAGERegressor, ResidualGATRegressor
#      13 from wildfire_gnn.training.losses_5b import (
#      14     build_target_weights,
#      15     classification_loss,
#    (...)     18     weighted_mse_loss,
#      19 )
#
# File c:\ProgramData\anaconda3\envs\wildfire_gnn\Lib\site-packages\torch_geometric\__init__.py:14
#      12 from .home import get_home_dir, set_home_dir
#      13 from .device import is_mps_available, is_xpu_available, device
# ---> 14 from .isinstance import is_torch_instance
#      15 from .debug import is_debug_enabled, debug, set_debug
#      17 import torch_geometric.utils
#
# File c:\ProgramData\anaconda3\envs\wildfire_gnn\Lib\site-packages\torch_geometric\isinstance.py:7
#       3 import torch
#       5 import torch_geometric.typing
# ----> 7 if torch_geometric.typing.WITH_PT20:
#       8     import torch._dynamo
#      11 def is_torch_instance(obj: Any, cls: Union[Type, Tuple[Type]]) -> bool:
#
# AttributeError: partially initialized module 'torch_geometric' has no attribute 'typing' (most likely due to a circular import)
